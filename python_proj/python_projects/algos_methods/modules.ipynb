# %%
import exceptions

# %%
import fib
print(fib.fib(5))
# Out:
# 8

# %%
print(exceptions.greet("Student"))
# Out:
# Hello, Student

# %%
import sys

# %%
import check
# Out:
# check

# %%
print(sys.modules)
# Out:
# {'sys': <module 'sys' (built-in)>, 'builtins': <module 'builtins' (built-in)>, '_frozen_importlib': <module 'importlib._bootstrap' (frozen)>, '_imp': <module '_imp' (built-in)>, '_warnings': <module '_warnings' (built-in)>, '_frozen_importlib_external': <module 'importlib._bootstrap_external' (frozen)>, '_io': <module 'io' (built-in)>, 'marshal': <module 'marshal' (built-in)>, 'posix': <module 'posix' (built-in)>, '_thread': <module '_thread' (built-in)>, '_weakref': <module '_weakref' (built-in)>, 'time': <module 'time' (built-in)>, 'zipimport': <module 'zipimport' (frozen)>, '_codecs': <module '_codecs' (built-in)>, 'codecs': <module 'codecs' from '/home/argo/anaconda3/envs/fastai2/lib/python3.8/codecs.py'>, 'encodings.aliases': <module 'encodings.aliases' from '/home/argo/anaconda3/envs/fastai2/lib/python3.8/encodings/aliases.py'>, 'encodings': <module 'encodings' from '/home/argo/anaconda3/envs/fastai2/lib/python3.8/encodings/__init__.py'>, 'encodings.utf_8': <module 'encodings.u
# ...

# %%
print(type(check))
# Out:
# <class 'module'>
